# %%
import pandas as pd
import numpy as np
import os
import tensorflow as tf
import cv2
from tensorflow import keras
from  matplotlib import pyplot as plt
import matplotlib.image as mpimg

import keras as k
from matplotlib import pyplot
from keras.preprocessing.image import ImageDataGenerator
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import time

def TicTocGenerator():
    # Generator that returns time differences
    ti = 0           # initial time
    tf = time.time() # final time
    while True:
        ti = tf
        tf = time.time()
        yield tf-ti # returns the time difference

TicToc = TicTocGenerator() # create an instance of the TicTocGen generator

# This will be the main function through which we define both tic() and toc()
def toc(tempBool=True):
    # Prints the time difference yielded by generator instance TicToc
    tempTimeInterval = next(TicToc)
    if tempBool:
        print( "Elapsed time: %f seconds.\n" %tempTimeInterval )

def tic():
    # Records a time in TicToc, marks the beginning of a time interval
    toc(False)

# %%
def create_dataset(img_folder,IMG_HEIGHT=256, IMG_WIDTH=256):
    tic()
    i=1
    img_data_array=[]
    class_name=[]
   
    for dir1 in os.listdir(img_folder):
        for file in os.listdir(os.path.join(img_folder, dir1)):
            
            if (i%100 == 0):
              print(i)
              toc()
              tic()
            i = i+1
            image_path= os.path.join(img_folder, dir1,  file)
            image= cv2.imread( image_path, cv2.COLOR_BGR2RGB)
            image=cv2.resize(image, (IMG_HEIGHT, IMG_WIDTH),interpolation = cv2.INTER_AREA)
            image=np.array(image)
            image = image.astype('float32')
            image /= 255 
            img_data_array.append(image)
            class_name.append(dir1)
    return img_data_array, class_name
# extract the image array and class name
img_data, class_name =create_dataset(r'/content/drive/MyDrive/CNN_image_3/CNN_image_3')
# Out:
# 100
# Elapsed time: 1.662821 seconds.
#
# 200
# Elapsed time: 1.650863 seconds.
#
# 300
# Elapsed time: 1.634647 seconds.
#
# 400
# Elapsed time: 1.647826 seconds.
#
# 500
# Elapsed time: 1.607360 seconds.
#
# 600
# Elapsed time: 1.648259 seconds.
#
# 700
# Elapsed time: 1.640536 seconds.
#
# 800
# Elapsed time: 1.625796 seconds.
#
# 900
# Elapsed time: 1.585570 seconds.
#
# 1000
# Elapsed time: 1.614007 seconds.
#
# 1100
# Elapsed time: 1.713386 seconds.
#
# 1200
# Elapsed time: 1.701984 seconds.
#
# 1300
# Elapsed time: 1.706253 seconds.
#
# 1400
# Elapsed time: 1.723078 seconds.
#
# 1500
# Elapsed time: 1.658324 seconds.
#
# 1600
# Elapsed time: 1.652619 seconds.
#
# 1700
# Elapsed time: 1.692363 seconds.
#
# 1800
# Elapsed time: 1.625513 seconds.
#
# 1900
# Elapsed time: 1.651849 seconds.
#
# 2000
# Elapsed time: 1.605530 seconds.
#
# 2100
# Elapsed time: 1.615618 seconds.
#
# 2200
# Elapsed time: 1.662984 seconds.
#
# 2300
# Elapsed time: 1.651012 seconds.
#
# 2400
# Elapsed time: 1.589433 seconds.
#
# 2500
# Elapsed time: 1.627387 seconds.
#
# 2600
# Elapsed time: 1.677031 seconds.
#
# 2700
# Elapsed time: 1.589884 seconds.
#
# 2800
# Elapsed time: 1.585094 seconds.
#
# 2900
# Elapsed time: 1.679276 seconds.
#
# 3000
# Elapsed time: 1.633891 seconds.
#
# 3100
# Elapsed time: 1.619322 seconds.
#
# 3200
# Elapsed time: 1.662743 seconds.
#
# 3300
# Elapsed time: 1.639590 seconds.
#
# 3400
# Elapsed time: 1.735897 seconds.
#
# 3500
# Elapsed time: 1.649748 seconds.
#
# 3600
# Elapsed time: 1.635306 seconds.
#
# 3700
# Elapsed time: 1.653319 seconds.
#
# 3800
# Elapsed time: 1.615835 seconds.
#
# 3900
# Elapsed time: 1.645875 seconds.
#
# 4000
# Elapsed time: 1.647307 seconds.
#
# 4100
# Elapsed time: 1.608622 seconds.
#
# 4200
# Elapsed time: 1.594051 seconds.
#
# 4300
# Elapsed time: 1.625969 seconds.
#
# 4400
# Elapsed time: 1.609822 seconds.
#
# 4500
# Elapsed time: 1.605980 seconds.
#
# 4600
# Elapsed time: 1.643038 seconds.
#
# 4700
# Elapsed time: 1.572857 seconds.
#
# 4800
# Elapsed time: 1.614685 seconds.
#
# 4900
# Elapsed time: 1.716122 seconds.
#
# 5000
# Elapsed time: 1.723313 seconds.
#
# 5100
# Elapsed time: 1.764834 seconds.
#
# 5200
# Elapsed time: 1.859787 seconds.
#
# 5300
# Elapsed time: 1.803033 seconds.
#
# 5400
# Elapsed time: 1.878630 seconds.
#
# 5500
# Elapsed time: 1.700862 seconds.
#
# 5600
# Elapsed time: 1.699410 seconds.
#
# 5700
# Elapsed time: 1.677430 seconds.
#
# 5800
# Elapsed time: 1.681204 seconds.
#
# 5900
# Elapsed time: 1.684163 seconds.
#
# 6000
# Elapsed time: 1.678439 seconds.
#
# 6100
# Elapsed time: 1.635991 seconds.
#
# 6200
# Elapsed time: 1.625867 seconds.
#
# 6300
# Elapsed time: 1.590423 seconds.
#
# 6400
# Elapsed time: 1.597001 seconds.
#
# 6500
# Elapsed time: 1.656826 seconds.
#
# 6600
# Elapsed time: 1.626349 seconds.
#
# 6700
# Elapsed time: 1.602718 seconds.
#
# 6800
# Elapsed time: 1.621492 seconds.
#
# 6900
# Elapsed time: 1.655150 seconds.
#
# 7000
# Elapsed time: 1.613780 seconds.
#
# 7100
# Elapsed time: 1.660485 seconds.
#
# 7200
# Elapsed time: 1.637099 seconds.
#
# 7300
# Elapsed time: 1.645386 seconds.
#
# 7400
# Elapsed time: 1.678818 seconds.
#
# 7500
# Elapsed time: 1.598816 seconds.
#
# 7600
# Elapsed time: 1.624899 seconds.
#
# 7700
# Elapsed time: 1.669637 seconds.
#
# 7800
# Elapsed time: 1.656376 seconds.
#
# 7900
# Elapsed time: 1.622669 seconds.
#
# 8000
# Elapsed time: 1.663959 seconds.
#
# 8100
# Elapsed time: 1.654853 seconds.
#
# 8200
# Elapsed time: 1.602255 seconds.
#
# 8300
# Elapsed time: 1.616228 seconds.
#
# 8400
# Elapsed time: 1.737421 seconds.
#
# 8500
# Elapsed time: 1.827935 seconds.
#
# 8600
# Elapsed time: 1.842085 seconds.
#
# 8700
# Elapsed time: 1.907388 seconds.
#
# 8800
# Elapsed time: 1.776284 seconds.
#
# 8900
# Elapsed time: 1.828768 seconds.
#
# 9000
# Elapsed time: 1.793787 seconds.
#
# 9100
# Elapsed time: 1.756125 seconds.
#
# 9200
# Elapsed time: 1.718780 seconds.
#
# 9300
# Elapsed time: 1.726762 seconds.
#
# 9400
# Elapsed time: 1.764621 seconds.
#
# 9500
# Elapsed time: 1.956661 seconds.
#
# 9600
# Elapsed time: 1.889827 seconds.
#
# 9700
# Elapsed time: 1.938946 seconds.
#
# 9800
# Elapsed time: 1.886209 seconds.
#
# 9900
# Elapsed time: 1.928845 seconds.
#
# 10000
# Elapsed time: 1.893185 seconds.
#
# 10100
# Elapsed time: 1.800323 seconds.
#
# 10200
# Elapsed time: 1.874814 seconds.
#
# 10300
# Elapsed time: 1.807879 seconds.
#
# 10400
# Elapsed time: 1.862127 seconds.
#
# 10500
# Elapsed time: 1.891249 seconds.
#
# 10600
# Elapsed time: 1.869431 seconds.
#
# 10700
# Elapsed time: 1.850465 seconds.
#
# 10800
# Elapsed time: 1.682403 seconds.
#
# 10900
# Elapsed time: 1.772219 seconds.
#
# 11000
# Elapsed time: 1.849706 seconds.
#
# 11100
# Elapsed time: 1.751935 seconds.
#
# 11200
# Elapsed time: 1.804773 seconds.
#
# 11300
# Elapsed time: 1.936688 seconds.
#
# 11400
# Elapsed time: 1.965566 seconds.
#
# 11500
# Elapsed time: 1.836546 seconds.
#
# 11600
# Elapsed time: 1.764396 seconds.
#
# 11700
# Elapsed time: 1.762171 seconds.
#
# 11800
# Elapsed time: 1.741709 seconds.
#
# 11900
# Elapsed time: 1.743134 seconds.
#
# 12000
# Elapsed time: 1.726895 seconds.
#
# 12100
# Elapsed time: 1.739066 seconds.
#
# 12200
# Elapsed time: 1.710799 seconds.
#
# 12300
# Elapsed time: 1.692095 seconds.
#
# 12400
# Elapsed time: 1.712343 seconds.
#
# 12500
# Elapsed time: 1.713042 seconds.
#
# 12600
# Elapsed time: 1.698162 seconds.
#
# 12700
# Elapsed time: 1.720722 seconds.
#
# 12800
# Elapsed time: 1.772471 seconds.
#
# 12900
# Elapsed time: 1.743959 seconds.
#
# 13000
# Elapsed time: 1.693794 seconds.
#
# 13100
# Elapsed time: 1.801106 seconds.
#
# 13200
# Elapsed time: 1.838130 seconds.
#
# 13300
# Elapsed time: 1.930643 seconds.
#
# 13400
# Elapsed time: 1.832366 seconds.
#
# 13500
# Elapsed time: 1.680568 seconds.
#
# 13600
# Elapsed time: 1.738464 seconds.
#
# 13700
# Elapsed time: 1.779836 seconds.
#
# 13800
# Elapsed time: 1.872351 seconds.
#
# 13900
# Elapsed time: 1.991198 seconds.
#
# 14000
# Elapsed time: 1.925547 seconds.
#
# 14100
# Elapsed time: 1.834171 seconds.
#
# 14200
# Elapsed time: 1.916225 seconds.
#
# 14300
# Elapsed time: 1.769935 seconds.
#
# 14400
# Elapsed time: 1.756627 seconds.
#
# 14500
# Elapsed time: 1.809348 seconds.
#
# 14600
# Elapsed time: 1.824464 seconds.
#
# 14700
# Elapsed time: 1.929542 seconds.
#
# 14800
# Elapsed time: 1.969592 seconds.
#
# 14900
# Elapsed time: 2.183466 seconds.
#
# 15000
# Elapsed time: 2.354887 seconds.
#
# 15100
# Elapsed time: 2.210237 seconds.

# %%
from numpy import array
from numpy import argmax
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
# define example
data = class_name
values = array(data)
print(values)
# integer encode
label_encoder = LabelEncoder()
integer_encoded = label_encoder.fit_transform(values)
print(integer_encoded)
# binary encode
onehot_encoder = OneHotEncoder(sparse=False)
integer_encoded = integer_encoded.reshape(len(integer_encoded), 1)
onehot_encoded = onehot_encoder.fit_transform(integer_encoded)
print(onehot_encoded)
# invert first example
inverted = label_encoder.inverse_transform([argmax(onehot_encoded[0, :])])
print(inverted)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-7a204eedc919> in <module>()
#       4 from sklearn.preprocessing import OneHotEncoder
#       5 # define example
# ----> 6 data = class_name
#       7 values = array(data)
#       8 print(values)
#
# NameError: name 'class_name' is not defined

# %%
class Same_net(tf.keras.Model):
    def __init__(self,
                     filters_1x1=4,
                     filters_3x3_reduce=4,
                     filters_3x3=4,
                     filters_5x5_reduce=4,
                     filters_5x5=4,
                     filters_pool_proj=4,
                     name='inception_3a',
                     inp_shapes = (256, 256, 3)):
      
        super(Same_net, self).__init__()
        self.conv1x1 = tf.keras.layers.Conv2D(filters_1x1, (1, 1), padding='same')
        
        self.conv3x3_reduce = tf.keras.layers.Conv2D(filters_3x3_reduce, (1, 1), padding='same')
        self.conv3x3 = tf.keras.layers.Conv2D(filters_3x3, (3, 3), padding='same')
        
        self.conv5x5_reduce = tf.keras.layers.Conv2D(filters_5x5_reduce, (1, 1), padding='same')
        self.conv5x5 = tf.keras.layers.Conv2D(filters_5x5, (5, 5), padding='same')
        
        self.convpool = tf.keras.layers.Conv2D(filters_1x1, (1, 1), padding='same')
        
        self.bn = tf.keras.layers.BatchNormalization()
        self.act = tf.keras.layers.Activation('relu')
        self.max_pool = tf.keras.layers.MaxPool2D((3, 3),strides=(1, 1), padding='same')
        self.Concat = tf.keras.layers.Concatenate()

    def call(self, inputs):
        
        b1 = self.conv1x1(inputs)
        b1_act = self.act(b1)
        
        b2 = self.conv3x3_reduce(inputs)
        b2_act = self.act(b2)
        b2_2 = self.conv3x3(b2_act)
        b2_2_act = self.act(b2_2)
        
        b3 = self.conv5x5_reduce(inputs)
        b3_act = self.act(b3)
        b3_2 = self.conv5x5(b3_act)
        b3_2_act = self.act(b3_2)
        
        b4 = self.max_pool(inputs)
        b4_2 = self.convpool(b4)
        b4_2_act = self.act(b4_2)
               
        output = self.Concat([b1_act, b2_2_act, b3_2_act, b4_2_act])
        return output

# %%
class Encod_2(tf.keras.Model):
    def __init__(self,filters_1x1=4):
        super(Encod_2, self).__init__()
        self.conv1x1 = tf.keras.layers.Conv2D(filters_1x1, (3, 3), padding='same')
        self.conv1x1_2 = tf.keras.layers.Conv2D(filters_1x1, (3, 3), padding='same')
        self.max_pool2 = tf.keras.layers.MaxPool2D((4, 4),strides=(3, 3), padding='same')
        self.act = tf.keras.layers.Activation('relu')
    def call(self, inputs):
        b1 = self.conv1x1(inputs)
        b1_act = self.act(b1)  
        b2 = self.conv1x1_2(b1_act)
        b2_act = self.act(b2)  
        b3 =   self.max_pool2(b2_act) 
        return b3

# %%
class Encod_comp(tf.keras.Model):
    def __init__(self,filters_1x1=4):
        super(Encod_comp, self).__init__()
        self.b1 = Same_net()
        #self.b12 = Same_net()
        #self.b13 = Same_net()
        
        self.b2 = Encod_2()
        self.b22 = Encod_2()
        self.b23 = Encod_2()

    def call(self, inputs):
        l1 = self.b1(inputs)
        l2 = self.b2(l1)
        #l3 = self.b12(l2)
        l4 = self.b22(l2)
        #l5 = self.b13(l4)
        l6 = self.b23(l4)

               
        return l6

# %%
class Class_out(tf.keras.Model):
    def __init__(self,filters_1x1=4):
        super(Class_out, self).__init__()
        self.Flat = tf.keras.layers.Flatten()
        self.D1 = tf.keras.layers.Dense(150, activation='relu')
        self.D2 = tf.keras.layers.Dense(40, activation='relu')
        self.D3 = tf.keras.layers.Dense(12, activation='relu')
        self.D4 = tf.keras.layers.Dense(4, activation='softmax')
        #self.D5 = tf.keras.layers.Softmax()
        #self.D0 = Encod_comp()

    def call(self, inputs):
      
        #l0 = self.D0(inputs)
        #l1 = self.Flat(l0)

        l1 = self.Flat(inputs)
        l2 = self.D1(l1)
        l3 = self.D2(l2)
        l4 = self.D3(l3)
        l5 = self.D4(l4)
        #l6 = self.D5(l5)
               
        return l5

# %%
class Decoder(tf.keras.Model):
    def __init__(self,filters_1x1=4,same_pad = 0):
        super(Decoder, self).__init__()
        if same_pad :
          self.conv1x1 = tf.keras.layers.Conv2DTranspose(filters_1x1, (3, 3), padding='same')
          self.conv1x1_2 = tf.keras.layers.Conv2DTranspose(filters_1x1, (3, 3), padding='same')
        else:
          self.conv1x1 = tf.keras.layers.Conv2DTranspose(filters_1x1, (3, 3), padding='valid')
          self.conv1x1_2 = tf.keras.layers.Conv2DTranspose(filters_1x1, (3, 3), padding='valid')
        self.UpSampling2D = tf.keras.layers.UpSampling2D((2, 2), interpolation='bilinear')
        self.act = tf.keras.layers.Activation('sigmoid')

    def call(self, inputs):
        b1 = self.conv1x1(inputs)
        b1_act = self.act(b1)  
        b2 = self.conv1x1_2(b1_act)
        b2_act = self.act(b2)  
        b3 =   self.UpSampling2D(b2_act) 
        return b3

# %%
class Decod_comp(tf.keras.Model):
    def __init__(self,filters_1x1=4):
        super(Decod_comp, self).__init__()
        self.b1 = Same_net()
        #self.b12 = Same_net()
        #self.b13 = Same_net()
        #self.b14 = Same_net()
        
        self.b2 = Decoder(same_pad = 0)
        self.b22 = Decoder(same_pad = 0)
        self.b23 = Decoder(same_pad = 1)
        self.b24 = Decoder(filters_1x1=3,same_pad = 1)

    def call(self, inputs):
        l1 = self.b1(inputs)
        l2 = self.b2(l1)
        #l3 = self.b12(l2)
        l4 = self.b22(l2)
        #l5 = self.b13(l4)
        l6 = self.b23(l4)
        #l7 = self.b14(l6)
        l8 = self.b24(l6)

               
        return l8

# %%
class Model_comp(tf.keras.Model):
    def __init__(self,filters_1x1=6):
        super(Model_comp, self).__init__()
        self.encoder = Encod_comp()
        self.decoder = Decod_comp()
        self.classifier = Class_out()
    def call(self, inputs):
        l1 = self.encoder(inputs)
        l2 = self.decoder(l1)
        l3 = self.classifier(l1)
        return [l2,l3]

# %%
steps_per_epoch = 400
model_1 = Model_comp()
model_1.compile(optimizer='adam', loss=['mean_squared_error' , 'categorical_crossentropy'], loss_weights=[1,10],metrics=['accuracy'])
#model_1.compile(loss="mean_squared_error", optimizer='RMSprop')
history = model_1.fit(x=img_data,
    y=[img_data, onehot_encoded],
    batch_size=64,
    epochs=10,
    verbose=1,
    callbacks=None,
    validation_split=0.2,
    shuffle=True,
    class_weight=None,
    sample_weight=None,
    validation_freq=2,)
